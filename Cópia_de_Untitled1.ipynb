# %% [markdown]
# <a href="https://colab.research.google.com/github/vandeco1730/Windons_RDP/blob/main/C%C3%B3pia_de_Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Recriando e salvando a planilha .xlsx com 100 coleções + planner, categorias e instruções de mockup
import pandas as pd
from datetime import datetime
from IPython.display import display # Substituindo caas_jupyter_tools por IPython.display

# Dados já definidos (parte inicial com detalhes reais/inspirados)
colecoes = [
    {"Nome":"Urban Minimal","Slogan":"Less, but better.","Paleta":"Preto, branco, cinza grafite","Visual":"Linhas finas, tipografia limpa","Estampas/Frases":"Simplicity wins; Focus mode","Publico":"Jovens urbanos, estética minimalista","Preco":"R$89–119","Categoria":"Lifestyle"},
    {"Nome":"Cozy Coffee","Slogan":"Wake your vibe.","Paleta":"Marrom latte, creme, caramelo","Visual":"Xícaras, vapor ilustrado","Estampas/Frases":"Caffeine & Peace; Brewed for good days","Publico":"Coffee lovers, baristas, estudantes","Preco":"R$79–109","Categoria":"Lifestyle"},
    {"Nome":"Quiet Luxury Essentials","Slogan":"Elegância silenciosa.","Paleta":"Off-white, bege, azul petróleo","Visual":"Tipografia serif premium","Estampas/Frases":"Understated; Timeless","Publico":"Classe média/alta, moda discreta","Preco":"R$109–159","Categoria":"Lifestyle"},
    {"Nome":"Beach Escape","Slogan":"Live by the tide.","Paleta":"Azul oceano, areia, coral","Visual":"Ondas, pranchas, sol","Estampas/Frases":"Salt on my skin; Ocean mind","Publico":"Turistas, surfistas","Preco":"R$89–119","Categoria":"Lifestyle"},
    {"Nome":"Slow Living","Slogan":"Respire devagar.","Paleta":"Pastéis neutros","Visual":"Ilustrações suaves e minimalistas","Estampas/Frases":"One thing at a time; Slow is beautiful","Publico":"Pessoas em busca de calma e bem-estar","Preco":"R$89–119","Categoria":"Lifestyle"},
    {"Nome":"Nomad Spirit","Slogan":"Keep moving.","Paleta":"Terracota, verde oliva","Visual":"Mapas, bússolas, mochilas","Estampas/Frases":"Born to roam; Where next?","Publico":"Mochileiros, nômades digitais","Preco":"R$89–129","Categoria":"Lifestyle"},
    {"Nome":"Farm Life","Slogan":"Roots & rhythm.","Paleta":"Verde musgo, marrom terra","Visual":"Galinhas, tratores, celeiros","Estampas/Frases":"Farm life is real life","Publico":"Rural lovers, country lifestyle","Preco":"R$89–119","Categoria":"Lifestyle"},
    {"Nome":"Vintage Roadtrip","Slogan":"Ride the old ways.","Paleta":"Vermelho retrô, amarelo queimado","Visual":"Vans retro, rotas, placas","Estampas/Frases":"Adventure awaits","Publico":"Viajantes nostálgicos","Preco":"R$89–129","Categoria":"Lifestyle"},
    {"Nome":"Garden Lovers","Slogan":"Grow with love.","Paleta":"Verde folha, rosé, bege","Visual":"Plantas, flores, pots aesthetic","Estampas/Frases":"Plant lady vibes","Publico":"Jardineiros e plant lovers","Preco":"R$79–109","Categoria":"Lifestyle"},
    {"Nome":"Mindful Living","Slogan":"Presente é tudo.","Paleta":"Azul claro, lilás","Visual":"Símbolos zen, pontos suaves","Estampas/Frases":"Inhale calm","Publico":"Saúde mental, meditação","Preco":"R$89–129","Categoria":"Lifestyle"},

    {"Nome":"Eco Raiz","Slogan":"Natureza em estado puro","Paleta":"Marrom terra, verde musgo, off-white","Visual":"Orgânico, rústico, texturas naturais","Estampas/Frases":"Do solo para a alma; Vista o essencial","Publico":"Consumidores eco-conscious","Preco":"R$79–189","Categoria":"Natureza"},
    {"Nome":"Golden Hour","Slogan":"Inspirada no pôr do sol","Paleta":"Laranja queimado, dourado, salmão","Visual":"Brilho suave, contornos quentes","Estampas/Frases":"Luz que te veste; Brilhe o dia todo","Publico":"Público feminino, fotógrafos","Preco":"R$89–199","Categoria":"Lifestyle"},
    {"Nome":"Cyber Girl","Slogan":"Futurista feminina","Paleta":"Preto, neon azul, neon rosa","Visual":"Cyberpunk leve","Estampas/Frases":"Futuro é agora; Modo cyborg ativado","Publico":"Jovens fãs de futurismo","Preco":"R$99–229","Categoria":"Estética"},
    {"Nome":"Clássicos Urbanos","Slogan":"Elegância da cidade","Paleta":"Cinza, vinho, azul marinho","Visual":"Minimalista sofisticado","Estampas/Frases":"Sinta a metrópole; Estilo que não dorme","Publico":"Profissionais urbanos","Preco":"R$89–219","Categoria":"Lifestyle"},
    {"Nome":"Café & aconchego","Slogan":"Conforto e aroma","Paleta":"Café, creme, caramelo","Visual":"Quente, aconchegante","Estampas/Frases":"Vista seu conforto; Energia boa no corpo","Publico":"Amantes de café e conforto","Preco":"R$79–169","Categoria":"Lifestyle"},
    {"Nome":"Origens Tribais","Slogan":"Arte étnica","Paleta":"Terracota, amarelo ocre, preto","Visual":"Padrões tribais contemporâneos","Estampas/Frases":"Ritmo ancestral; Carregue sua força","Publico":"Público que gosta de cultura e padrões","Preco":"R$89–209","Categoria":"Cultural"},
    {"Nome":"Tinta Fresca","Slogan":"Estética artística","Paleta":"Azul royal, vermelho, verde profundo","Visual":"Pinceladas e splashes","Estampas/Frases":"Vista sua arte; Seja a tela","Publico":"Artistas e criativos","Preco":"R$99–189","Categoria":"Arte"},
    {"Nome":"Anime Lovers","Slogan":"Inspirada em mangás","Paleta":"Preto, branco, rosa, azul bebê","Visual":"Olhos grandes, linhas marcantes","Estampas/Frases":"Modo protagonista; Força de herói","Publico":"Fãs de anime","Preco":"R$89–179","Categoria":"Geek"},
    {"Nome":"Minimal Clean","Slogan":"Leveza absoluta","Paleta":"Branco gelo, areia, cinza claro","Visual":"Ultra minimalista","Estampas/Frases":"Menos é mais; Pureza no estilo","Publico":"Minimalistas","Preco":"R$79–169","Categoria":"Lifestyle"},
    {"Nome":"Noite Estelar","Slogan":"Céu e constelações","Paleta":"Azul petróleo, dourado, preto","Visual":"Estrelas, constelações, lua","Estampas/Frases":"Vista seu brilho; Constelação própria","Publico":"Astro lovers","Preco":"R$99–219","Categoria":"Estética"}
]

# A partir daqui vamos gerar entradas plausíveis para coleções 31 a 100
nomes_31_100 = [
"Flores Tropicais","Futuro Minimal","Denim Lovers","Poemas Visuais","Selva Neon","Raio & Trovão","Luxo Urbano","Forma & Movimento","Flores Secas","Golden Pink",
"Surf Mood","Beleza Serena","Chic Natural","Festival Dreams","Códigos Secretos","Cosmic Glow","Glam Punk","Street Legends","Candy Vibes","Energia Solar",
"Inverno Doce","Digital Paradise","Arte Impressa","Pastel Punk","Sons da Cidade","Tropical Sunset","Outono Quente","Forma Livre","Aquarela","Black & Gold",
"Mistério Lunar","Magia Azul","Pura Energia","Selvagem Feminina","Cores do Infinito","Luz & Sombra","Futurismo Suave","Chamas Urbanas","Céu Roxo","Retro Lovers",
"Planeta Verde","Arte Moderna","Chill Vibes","Rituais Naturais","Pop Stars","Aurora Boreal","Arco-Íris Minimal","Sussurro Floral","Tons de Caramelo","Cidades Futuras",
"Horizonte Rosa","Beleza Oculta","Viagem no Tempo","Sombra & Brilho","Água Viva","Geometria Suave","Cores Urbanas","Pura Essência","Arte Desconstruída","Vento Livre",
"Sol & Mar","Poesia Lunar","Cores que Cantam","Natureza Azul","Jardim Rosa","Vibração Neon","Luz Interior","Fantasia Urbana","Raízes Modernas","Universo Feminino"
]

import random
random.seed(42)

for i, nome in enumerate(nomes_31_100, start=31):
    colecoes.append({
        "Nome": nome,
        "Slogan": f"{nome} — coleção exclusiva",
        "Paleta": random.choice(["Pastel", "Vibrante", "Neutro", "Terroso", "Neon"]) + " (" + random.choice(["rosa","azul","verde","dourado","preto"]) + ")",
        "Visual": random.choice(["Ilustrações florais","Formas geométricas","Texturas industriais","Neon e brilho","Aquarela suave"]),
        "Estampas/Frases": f"Frase exemplo {i}; Estampa exemplo {i}",
        "Publico": random.choice(["Jovens","Adultos","Mulheres","Homens","Público unissex"]),
        "Preco": random.choice(["R$79–129","R$89–159","R$99–219","R$69–119"]),
        "Categoria": random.choice(["Estética","Arte","Lifestyle","Natureza","Cultural","Geek"])
    })

# Criando DataFrame principal
df = pd.DataFrame(colecoes)

# Criando planner de lançamento (modelo) com 12 semanas
planner_rows = []
for week in range(1,13):
    planner_rows.append({
        "Semana": f"Semana {week}",
        "Objetivo": random.choice(["Pré-lançamento", "Lançamento", "Pós-lançamento", "Promoção"]),
        "Tarefas": "Design | Mockups | Anúncios | E-mail marketing",
        "Canais": random.choice(["Instagram, TikTok, E-mail","Facebook Ads, Google","Pinterest, Loja"]),
        "KPIs": "CTR, ROAS, Conversão",
        "Orcamento": random.choice(["R$500","R$1000","R$1500","R$3000"])
    })

df_planner = pd.DataFrame(planner_rows)

# Criando sheet de categorias e mapear coleções para categorias (resumo)
categorias = df.groupby("Categoria").size().reset_index(name="Quantidade")
df_categorias = categorias.copy()

# Sheet de instruções rápidas de mockup e recursos
instrucoes = [
    {"Assunto":"Gerar mockups","Conteudo":"Use serviços como Placeit, Smartmockups ou mockups locais no Photoshop. Gere mockups em 3 variações: produto principal, detalhe e lifestyle."},
    {"Assunto":"Specs de arquivo","Conteudo":"Exportar artes em PNG 300 DPI com fundo transparente. Tamanho recomendado 3500x4200 px para camisetas."},
    {"Assunto":"Canais de venda","Conteudo":"Loja própria (Shopify), marketplaces (Etsy), Redes sociais (Instagram, TikTok). Use segmentação por interesses e lookalikes."},
    {"Assunto":"Preços e margem","Conteudo":"Calcule margem 40-60% após custo POD e anúncios. Teste preços por A/B."}
]
df_instrucoes = pd.DataFrame(instrucoes)

# Salvar tudo em um arquivo .xlsx com múltiplas sheets
filename = "/mnt/data/colecoes_pod_completo.xlsx"
with pd.ExcelWriter(filename, engine="openpyxl") as writer:
    df.to_excel(writer, sheet_name="Coleções", index=False)
    df_planner.to_excel(writer, sheet_name="Planner Lançamento", index=False)
    df_categorias.to_excel(writer, sheet_name="Categorias", index=False)
    df_instrucoes.to_excel(writer, sheet_name="Mockup & Specs", index=False)

# Mostrar as primeiras linhas para o usuário
print("Coleções (preview)")
display(df.head(20))
print("Planner (preview)")
display(df_planner.head(12))

# Exibir caminho do arquivo salvo
filename
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-372351863.py in <cell line: 0>()
#       2 import pandas as pd
#       3 from datetime import datetime
# ----> 4 from caas_jupyter_tools import display_dataframe_to_user
#       5
#       6 # Dados já definidos (parte inicial com detalhes reais/inspirados)
#
# ModuleNotFoundError: No module named 'caas_jupyter_tools'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
```python
# Instalação de uma biblioteca de exemplo (substitua 'nome_da_biblioteca' pela biblioteca desejada)
# !pip install nome_da_biblioteca
```

# %% [markdown]
# ```markdown
# Basta substituir `nome_da_biblioteca` pelo nome da biblioteca que você deseja instalar (por exemplo, `pandas`, `numpy`, `scikit-learn`). O `!` no início indica que é um comando de shell.
# ```

# %%
# O pacote caas_jupyter_tools não foi encontrado. A dependência foi removida da célula principal.
# Out:
# ERROR: Could not find a version that satisfies the requirement caas_jupyter_tools (from versions: none)
# ERROR: No matching distribution found for caas_jupyter_tools
